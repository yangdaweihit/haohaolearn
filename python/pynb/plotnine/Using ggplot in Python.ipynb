# %% [markdown]
# # [Using ggplot in Python: Visualizing Data With plotnine](https://realpython.com/ggplot-python/)

# %%
from plotnine.data import economics, mpg, huron
from plotnine import ggplot, aes, facet_grid, geom_line, geom_point, stat_bin, geom_bar, geom_boxplot, scale_x_timedelta, labs, coord_flip
from plotnine import theme_dark, theme_xkcd

# %%
economics
# Out:
#           date      pce     pop  psavert  uempmed  unemploy
# 0   1967-07-01    507.4  198712     12.5      4.5      2944
# 1   1967-08-01    510.5  198911     12.5      4.7      2945
# 2   1967-09-01    516.3  199113     11.7      4.6      2958
# 3   1967-10-01    512.9  199311     12.5      4.9      3143
# 4   1967-11-01    518.1  199498     12.5      4.7      3066
# ..         ...      ...     ...      ...      ...       ...
# 569 2014-12-01  12122.0  320201      5.0     12.6      8688
# 570 2015-01-01  12080.8  320367      5.5     13.4      8979
# 571 2015-02-01  12095.9  320534      5.7     13.1      8705
# 572 2015-03-01  12161.5  320707      5.2     12.2      8575
# 573 2015-04-01  12158.9  320887      5.6     11.7      8549
#
# [574 rows x 6 columns]

# %%
(
    ggplot(economics)  # What data to use
    + aes(x="date", y="pop")  # What variable to use
    + geom_line()  # Geometric object to use for drawing
)
# Out:
# <ggplot: (8761769424875)>

# %%
ggplot(economics) + aes(x="date", y= "unemploy") + geom_line()
# Out:
# <ggplot: (8761769159996)>

# %%
mpg
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 0           audi      a4    1.8  1999    4    auto(l5)   f   18   29  p
# 1           audi      a4    1.8  1999    4  manual(m5)   f   21   29  p
# 2           audi      a4    2.0  2008    4  manual(m6)   f   20   31  p
# 3           audi      a4    2.0  2008    4    auto(av)   f   21   30  p
# 4           audi      a4    2.8  1999    6    auto(l5)   f   16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ... ..
# 229   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 230   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 231   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 232   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 233   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#        class
# 0    compact
# 1    compact
# 2    compact
# 3    compact
# 4    compact
# ..       ...
# 229  midsize
# 230  midsize
# 231  midsize
# 232  midsize
# 233  midsize
#
# [234 rows x 11 columns]

# %%
ggplot(mpg) + aes(x="class", y= "hwy") + geom_point()
# Out:
# <ggplot: (8761769046557)>

# %%
ggplot(mpg) + aes(x="class") + geom_bar()
# Out:
# <ggplot: (8761769022615)>

# %%
huron
# Out:
#     year   level  decade
# 0   1875  580.38    1870
# 1   1876  581.86    1870
# 2   1877  580.97    1870
# 3   1878  580.80    1870
# 4   1879  579.79    1870
# ..   ...     ...     ...
# 93  1968  578.52    1960
# 94  1969  579.74    1960
# 95  1970  579.31    1970
# 96  1971  579.89    1970
# 97  1972  579.96    1970
#
# [98 rows x 3 columns]

# %%
ggplot(huron) + aes(x="level") + stat_bin(bins=30) + geom_bar()
# Out:
# <ggplot: (8761769398251)>

# %%
(
  ggplot(huron)
  + aes(x="factor(decade)", y="level")
  + geom_boxplot()
)
# Out:
# <ggplot: (8761769656498)>

# %%
(
    ggplot(economics)
    + aes(x="date", y="pop")
    + scale_x_timedelta(name="Years since 1970")
    + labs(title="Population Evolution", y="Population")
    + geom_line()
)
# Out:
# <ggplot: (8761770705629)>

# %%
ggplot(mpg) + aes(x="class") + geom_bar() + coord_flip()
# Out:
# <ggplot: (8761768777494)>

# %%
(
    ggplot(mpg)
    + facet_grid(facets="year~class")
    + aes(x="displ", y="hwy")
    + labs(
        x="Engine Size",
        y="Miles per Gallon",
        title="Miles per Gallon for Each Year and Vehicle Class",
    )
    + geom_point()
)
# Out:
# <ggplot: (8761768247744)>

# %%
(
    ggplot(mpg)
    + facet_grid(facets="year~class")
    + aes(x="displ", y="hwy")
    + labs(
        x="Engine Size",
        y="Miles per Gallon",
        title="Miles per Gallon for Each Year and Vehicle Class",
    )
    + geom_point()
    + theme_dark()
)
# Out:
# <ggplot: (8761769037761)>

# %%
(
    ggplot(mpg)
    + facet_grid(facets="year~class")
    + aes(x="displ", y="hwy")
    + labs(
        x="Engine Size",
        y="Miles per Gallon",
        title="Miles per Gallon for Each Year and Vehicle Class",
    )
    + geom_point()
    + theme_xkcd()
)
# Out:
# <ggplot: (8761769048329)>

# %%
(
    ggplot(mpg)
    + aes(x="cyl", y="hwy", color="class")
    + labs(
        x="Engine Cylinders",
        y="Miles per Gallon",
        color="Vehicle Class",
        title="Miles per Gallon for Engine Cylinders and Vehicle Classes",
    )
    + geom_point()
)
# Out:
# <ggplot: (8761768516554)>
